# %% [markdown]
# <a href="https://colab.research.google.com/github/NYUExperimentalPhysics1-2021/Assignment0/blob/main/Copy_of_Assignment3-Feedback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #[PyMan 0.9.31 Introduction to Python for Science](https://physics.nyu.edu/pine/pymanual/html/pymanMaster.html)
#
# ###The following exercises correspond to chapter [5: Plotting](https://physics.nyu.edu/pine/pymanual/html/chap5/chap5_plot.html)

# %%
#run this block first
#this is the now standard way of interfacing with numpy and pyplot
#when you do the excercises below....
#put np. in front of any numpy commands
#e.g. np.arange instead of arange
#put plt. in front of any pyplot commands
#e.g. plt.plot
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##5.5.1
#
# Plot the function $y=3x^2$ for $-1\leq x \leq 3$ as a continuous line. Include enough points so that the curve you plot appears smooth. Label the axes $x$ and $y$. (Hint, you should first define a numpy array between -1 and 3 for x; hint hint np.linspace is your friend)

# %%
##USE THIS CODE BLOCK TO COMPLETE EXERCISE 5.5.1##

x = np.linspace(-1,3,30)
y = 3*(x**2)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel("y")
plt.show()

# %% [markdown]
# ##5.5.2
#
# Plot the following function for $-15\leq x \leq 15$:
#
# $y = \frac{\cos{x}}{1+\frac{1}{5}x^2}$
#
# Include enough points so that the curve you plot appears smooth. Label the axes $x$ and $y$.

# %%
##USE THIS CODE BLOCK TO COMPLETE EXERCISE 5.5.2##

x = np.linspace(-15,15,300)
y = (np.cos(x))/(1+(0.2*(x**2)))
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel("y")
plt.show()

# %% [markdown]
# ##5.5.3
#
# Plot the functions $\sin{x}$ and $\cos{x}$ _vs_ $x$ on the same plot with $x$ going from $-\pi$ to $\pi$. Make sure hte limits of the $x$-axis do not extand beyond the limits of the data. Plot $\sin{x}$ in the color green and $\cos{x}$ in the color black and include a legend to label the two curves. Place the legend within the plot, but such that it does not cover either of the sine or cosine traces.

# %%
##USE THIS CODE BLOCK TO COMPLETE EXERCISE 5.5.3##

x = np.linspace(-np.pi,np.pi,100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1,"g",label='sin(x)')
plt.plot(x,y2,"k",label='cos(x)')
plt.legend(loc='upper left')

# %%
##USE THIS CODE BLOCK TO COMPLETE EXERCISE 5.5.4##

# %% [markdown]
# ##5.5.5
#
# Use MatPlotLib's function `hist` along with NumPy's functions `random.rand` and `random.randn` to create the histogram graphs shown in Fig. _[Histograms of random numbers.](https://physics.nyu.edu/pine/pymanual/html/chap3/chap3_arrays.html#fig-randhistos)_

# %%
##USE THIS CODE BLOCK TO COMPLETE EXERCISE 5.5.5##

x1 = np.random.randn(10000)
x2 = np.random.rand(1000)
plt.hist(x1,36,density=True,color='green',ec='black')
plt.hist(x2,10,density=True,color='blue',ec='black')
plt.show()

# %% [markdown]
# **Comment**:

# %%
# Okay, you can make it more similar with those plots in the following way:
x1 = np.random.randn(10000)
x2 = np.random.rand(10000)
plt.hist(x1, 40, density = True, color= 'green', ec = 'gray', alpha = 0.5 )
plt.hist(x2, 10, density = True, color= 'blue', ec = 'gray', alpha = 0.5 )
plt.xlabel('x')
plt.ylabel('P(x)')
plt.show()

# %% [markdown]
# 5.5.6
#
# Plot force _vs_ distance with error bars using the following data:
#
#
# ```
# d=np.array([0.38, 0.64, 0.91, 1.26, 1.41, 1.66, 1.90, 2.18]) #distance
# f=np.array([1.4, 1.65, 3.0, 3.95, 4.3, 5.20, 6.85, 7.4]) #force
# df=np.array([ 0.4, 0.5, 0.4, 0.5, 0.6, 0.5, 0.5, 0.4]) #error in force
# ```
# Your plot should also include a visual straight "best fit" to the data as well as visual "fits" that give the smallest and largest slopes consistent with the data. Note, you only need two points to define a straight line so the straight lines you draw on the plot should be arrays of length 2 and no longer. All of your fitted lines should lie _behind_ the data. Try to make your plot look like the one below. _In addition_, add a legend to your plot that gives the slope with its uncertainty obtained from your visual fits to the data.
#
# "Visual fit" means adjust the slope and intercept until it looks good to you by eye. Once you learn how to do a real fit, you should never do this again.
#
# ![image.png](data:image/png;base64,...)
#
# The web page [http://matplotlib.org/api/pyplot_summary.html](http://matplotlib.org/api/pyplot_summary.html) gives a summary of the main plotting commands available in MatPlotLib. The two important ones here are `plot` and `errorbar`, which make regular plots and plots with error bars, respectively. You will find the following keyword arguments useful: `yerr`, `ls`, `marker`, `mfc`, `mec`, `ms`, and `ecolor`, which you can find described by clicking on the `errorbar` function link on the web page cited above.

# %%
##USE THIS CODE BLOCK TO COMPLETE EXERCISE 5.5.6##

d=np.array([0.38, 0.64, 0.91, 1.26, 1.41, 1.66, 1.90, 2.18]) #distance
f=np.array([1.4, 1.65, 3.0, 3.95, 4.3, 5.20, 6.85, 7.4]) #force
df=np.array([ 0.4, 0.5, 0.4, 0.5, 0.6, 0.5, 0.5, 0.4]) #error in force
x = [0.2, 2.4]
y = [0.4, 8.2]
m1 = np.diff(y)/np.diff(x)
print(m1)
x2 = [0.2, 2.4]
y2 = [0, 8.5]
m2 = np.diff(y2)/np.diff(x2)
print(m2)
x3 = [0.2, 2.4]
y3 = [0.8, 7.9]
m3 = np.diff(y3)/np.diff(x3)
plt.figure(1,figsize=(6,4))
plt.plot(x,y)
plt.plot(x2,y2,"g")
plt.plot(x3,y3,"g")
plt.errorbar(d,f,yerr=df,fmt='D',mfc='yellow',mec='red',ms=8,mew=1,ecolor='red',capsize=3)
plt.xlabel('Distance(cm)')
plt.ylabel('Force(N)')
plt.plot(x,y,"k",label='slope: 3.5')
plt.plot(x2,y2,"g",label='visualFit1',linestyle="--")
plt.plot(x3,y3,"b",label='visualFit2',linestyle="--")
plt.legend(loc='lower right')
# Out:
# [3.54545455]
# [3.86363636]

# %% [markdown]
# **Comment**:

# %%
# Okay: Below is how you can include your best-fit uncertainty in the legend:

d=np.array([0.38, 0.64, 0.91, 1.26, 1.41, 1.66, 1.90, 2.18]) #distance
f=np.array([1.4, 1.65, 3.0, 3.95, 4.3, 5.20, 6.85, 7.4]) #force
df=np.array([0.4, 0.5, 0.4, 0.5, 0.6, 0.5, 0.5, 0.4]) #error in force
plt.figure(1, figsize=(6, 4))

fitting_x = np.array([0.2, 2.4])
min_slope_y = np.array([1.2, 7.5])
max_slope_y = np.array([0.3, 8.2])
best_slope_y = np.array([np.average([1.2, 0.3]), np.average([7.5, 8.2])])

slope_min = (7.5 - 1.2)/(2.4 - 0.2)
slope_max = (8.2 - 0.3)/(2.4 - 0.2)
best_slope = np.average([slope_min, slope_max])
slope_uncertainty = np.average([np.abs(best_slope - slope_min), np.abs(best_slope - slope_max)])

plt.errorbar(d, f,  yerr = df, fmt='d', mfc = 'yellow', mec = 'red', ms = 10, mew = 0.9, ecolor='r', capsize = 4)
plt.plot(fitting_x, min_slope_y, color = 'gray', linestyle='dashed', zorder = -1)
plt.plot(fitting_x, max_slope_y,  color = 'gray', linestyle='dashed', zorder = -1)
plt.plot(fitting_x, best_slope_y,  color = 'black', linestyle='-', zorder = -1, label = "Best slope = {:0.2f} $\pm$ {:0.2f}".format(best_slope, slope_uncertainty))

plt.xlim(0, 2.5)
plt.ylim(0, 9)
plt.xlabel('distance (cm)')
plt.ylabel('force (N)')
plt.legend()
plt.show()
